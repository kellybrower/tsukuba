# %%
import requests
r = requests.get('http://www.global.tsukuba.ac.jp/map/bus/route-c10?language=en')

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html  lang="en" dir="ltr" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: h

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
bus_station = soup.find_all('div', attrs= {'class': 'field-content'})
bus_day = soup.find_all('div', attrs= {'class': 'bus-title'})
bus_time = soup.find_all('div', attrs={'class':'bus-time'})
[bus_station[0], bus_day[0], bus_time[0]]

#assign variables to the content we want, ie, station, day, time
# Out:
# [<div class="field-content"><h2>Clockwise Route</h2></div>,
#  <div class="bus-title"><strong>Weekday</strong></div>,
#  <div class="bus-time">06:00, 06:40, 07:20, 07:50, 08:00, 08:20, 08:40, 09:00, 09:20, 09:40, 10:00, 10:20, 10:40, 11:00, 11:20, 11:40, 12:00, 12:20, 12:40, 13:00, 13:20, 13:40, 14:00, 14:20, 14:40, 15:00, 15:20, 15:40, 16:00, 16:20, 16:40, 17:00, 17:20, 17:40, 18:00, 18:20, 18:40, 19:00, 19:20, 19:40, 20:00, 20:20, 20:40, 21:00, 21:40, 22:20</div>]

# %%
first_time=bus_time[0]
first_time
first_day = bus_day[0]
first_day
[first_day.contents, first_time.contents]
# Out:
# <div class="bus-time">06:00, 06:40, 07:20, 07:50, 08:00, 08:20, 08:40, 09:00, 09:20, 09:40, 10:00, 10:20, 10:40, 11:00, 11:20, 11:40, 12:00, 12:20, 12:40, 13:00, 13:20, 13:40, 14:00, 14:20, 14:40, 15:00, 15:20, 15:40, 16:00, 16:20, 16:40, 17:00, 17:20, 17:40, 18:00, 18:20, 18:40, 19:00, 19:20, 19:40, 20:00, 20:20, 20:40, 21:00, 21:40, 22:20</div>

# %%
first_station = station[4]
first_station.find('a').text

#extract bus station title
# Out:
# 'Tsukuba Medical Center Mae'

# %%
first_time = bus_time[0]
first_time.text
# Out:
# '06:00, 06:40, 07:20, 07:50, 08:00, 08:20, 08:40, 09:00, 09:20, 09:40, 10:00, 10:20, 10:40, 11:00, 11:20, 11:40, 12:00, 12:20, 12:40, 13:00, 13:20, 13:40, 14:00, 14:20, 14:40, 15:00, 15:20, 15:40, 16:00, 16:20, 16:40, 17:00, 17:20, 17:40, 18:00, 18:20, 18:40, 19:00, 19:20, 19:40, 20:00, 20:20, 20:40, 21:00, 21:40, 22:20'

# %%
first_day.find('strong').text
# Out:
# 'Weekday'

# %%
for s in bus_station:
    print(s.text)
# Out:
# Clockwise Route
# Tsukuba Center
# Azuma Sho-gakko
# Tsukuba Daigaku Kasuga Area Mae
# Tsukuba Medical Center Mae
# Tsukuba Daigaku Byoin Iriguchi
# Oikoshi Gakusei Shukusha Mae
# Hirasuna Gakusei Shukusha Mae
# Tsukuba Daigaku Nishi
# Daigaku Kaikan Mae
# Dai-Ichi Area Mae
# Dai-San Area Mae
# Niji no Hiroba
# Nohrin Gijutsu Center
# Ichinoya Gakusei Shukusha Mae
# Daigaku Shokubutsu Mihon-en
# TARA Center Mae
# Tsukuba Daigaku Chuo
# Daigaku Koen
# Matsumi Ike
# Amakubo San Chome
# Gasshukujo
# Amakubo Ike
# Amakubo Ni Chome
# Oikoshi Shukusha Higashi
# Medical Center Byoin
# Tsukuba Medical Center Mae
# Tsukuba Daigaku Kasuga Area Mae
# Azuma Sho-gakko
# Tsukuba Center
# Counterclockwise Route
# Tsukuba Center
# Azuma Sho-gakko
# Tsukuba Daigaku Kasuga Area Mae
# Tsukuba Medical Center Mae
# Medical Center Byoin
# Oikoshi Shukusha Higashi
# Amakubo Ni Chome
# Amakubo Ike
# Gasshukujo
# Amakubo San Chome
# Matsumi Ike
# Daigaku Koen
# Tsukuba Daigaku Chuo
# TARA Center Mae
# ...

# %%
days = []
times = []
stops = []
for d in bus_day:
    day = d.find('strong').text
    days.append(day)
for s in bus_station:
    station = s.text
    stops.append(station)
for t in bus_time:
    time = t.text
    times.append(time)
# Out:
# ['Clockwise Route',
#  'Tsukuba Center',
#  'Azuma Sho-gakko',
#  'Tsukuba Daigaku Kasuga Area Mae',
#  'Tsukuba Medical Center Mae',
#  'Tsukuba Daigaku Byoin Iriguchi',
#  'Oikoshi Gakusei Shukusha Mae',
#  'Hirasuna Gakusei Shukusha Mae',
#  'Tsukuba Daigaku Nishi',
#  'Daigaku Kaikan Mae',
#  'Dai-Ichi Area Mae',
#  'Dai-San Area Mae',
#  'Niji no Hiroba',
#  'Nohrin Gijutsu Center',
#  'Ichinoya Gakusei Shukusha Mae',
#  'Daigaku Shokubutsu Mihon-en',
#  'TARA Center Mae',
#  'Tsukuba Daigaku Chuo',
#  'Daigaku Koen',
#  'Matsumi Ike',
#  'Amakubo San Chome',
#  'Gasshukujo',
#  'Amakubo Ike',
#  'Amakubo Ni Chome',
#  'Oikoshi Shukusha Higashi',
#  'Medical Center Byoin',
#  'Tsukuba Medical Center Mae',
#  'Tsukuba Daigaku Kasuga Area Mae',
#  'Azuma Sho-gakko',
#  'Tsukuba Center',
#  'Counterclockwise Route',
#  'Tsukuba Center',
#  'Azuma Sho-gakko',
#  'Tsukuba Daigaku Kasuga Area Mae',
#  'Tsukuba Medical Center Mae',
#  'Medical Center Byoin',
# ...

# %%
records = list(zip(days, times, stops))
records
# Out:
# [('Weekday',
#   '06:00, 06:40, 07:20, 07:50, 08:00, 08:20, 08:40, 09:00, 09:20, 09:40, 10:00, 10:20, 10:40, 11:00, 11:20, 11:40, 12:00, 12:20, 12:40, 13:00, 13:20, 13:40, 14:00, 14:20, 14:40, 15:00, 15:20, 15:40, 16:00, 16:20, 16:40, 17:00, 17:20, 17:40, 18:00, 18:20, 18:40, 19:00, 19:20, 19:40, 20:00, 20:20, 20:40, 21:00, 21:40, 22:20',
#   'Clockwise Route'),
#  ('Weekend/Holiday',
#   '06:00, 06:40, 07:20, 08:00, 08:40, 09:20, 10:00, 10:40, 11:20, 12:00, 12:40, 13:20, 14:00, 14:40, 15:20, 16:00, 16:40, 17:20, 18:00, 18:40, 19:20, 20:00, 20:40, 21:20, 22:00, 22:40',
#   'Tsukuba Center'),
#  ('Weekday', 'No Data Available', 'Azuma Sho-gakko'),
#  ('Weekend/Holiday', 'No Data Available', 'Tsukuba Daigaku Kasuga Area Mae'),
#  ('Weekday', 'No Data Available', 'Tsukuba Medical Center Mae'),
#  ('Weekend/Holiday', 'No Data Available', 'Tsukuba Daigaku Byoin Iriguchi'),
#  ('Weekday', 'No Data Available', 'Oikoshi Gakusei Shukusha Mae'),
# ...

# %%
import pandas as pd
df = pd.DataFrame(records, columns = ['days', 'times', 'stops'])

# %%
df
# Out:
#                days                                              times  \
# 0           Weekday  06:00, 06:40, 07:20, 07:50, 08:00, 08:20, 08:4...
# 1   Weekend/Holiday  06:00, 06:40, 07:20, 08:00, 08:40, 09:20, 10:0...
# 2           Weekday                                  No Data Available
# 3   Weekend/Holiday                                  No Data Available
# 4           Weekday                                  No Data Available
# 5   Weekend/Holiday                                  No Data Available
# 6           Weekday                                  No Data Available
# 7   Weekend/Holiday                                  No Data Available
# 8           Weekday  06:04, 06:44, 07:24, 07:54, 08:04, 08:24, 08:4...
# 9   Weekend/Holiday  06:04, 06:44, 07:24, 08:04, 08:44, 09:24, 10:0...
# 10          Weekday  06:05, 06:45, 07:25, 07:55, 08:05, 08:25, 08:4...
# 11  Weekend/Holiday  06:05, 06:45, 07:25, 08:05, 08:45, 09:25, 10:0...
# ...
